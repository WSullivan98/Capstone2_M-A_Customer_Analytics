# %%
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
#%inline matplotlib
plt.style.use('ggplot')

# %% [markdown]
# # Load Data:
# * open in excel
# * Select tab "Product Saels by State and Customer"
# * remove first 5 lines of Quickbooks report header
# * save as to csv with underscore between words

# %%
sales_2015 = pd.read_csv('../data/raw/CLTV Project Data/product_sales_by_state_and_customer_2015.csv',parse_dates=['Date'])
sales_2016 = pd.read_csv('../data/raw/CLTV Project Data/poduct_sales_by_state_and_customer_2016.csv',parse_dates=['Date'])
sales_2017 = pd.read_csv('../data/raw/CLTV Project Data/product_sales_by_state_and_customer_2017.csv',parse_dates=['Date'])
sales_2018 = pd.read_csv('../data/raw/CLTV Project Data/product_sales_by_state_and_customer_2018.csv',parse_dates=['Date'])
sales_2019 = pd.read_csv('../data/raw/CLTV Project Data/Product Sales by State and Customer 2019.csv',parse_dates=['Date'])
sales_2020 = pd.read_csv('../data/raw/CLTV Project Data/Product Sales by State and Customer 2020.csv',parse_dates=['Date'])

# %%
sales_2015.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2015-05-18        INV13700
# 1   NaN  Invoice 2015-01-14        INV13192
# 2   NaN  Invoice 2015-01-27        INV13256
# 3   NaN  Invoice 2015-02-12        INV13341
# 4   NaN  Invoice 2015-02-16        INV13356
#
#                                          Description  Qty. Sold Sales Price  \
# 0  100 range 78" ActivBoard - 2 teacher ActivPen5...        5.0    $601.30
# 1  100 range 78" ActivBoard - 2 teacher ActivPen5...        2.0    $601.30
# 2  100 range 78" ActivBoard - 2 teacher ActivPen5...        2.0    $601.30
# 3  100 range 78" ActivBoard - 2 teacher ActivPen5...        2.0    $601.30
# 4  100 range 78" ActivBoard - 2 teacher ActivPen5...        2.0    $599.00
#
#       Revenue Address: Billing Address State Customer/Project: Company Name
# 0  $3,006.50                              CA    Roosevelt Elementary School
# 1  $1,202.60                              NV  Bud Beasley Elementary School
# ...

# %%
sales_2016.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2016-06-27        INV15412
# 1   NaN  Invoice 2016-10-20        INV15883
# 2   NaN  Invoice 2016-01-26        INV14862
# 3   NaN  Invoice 2016-02-09        INV14918
# 4   NaN  Invoice 2016-02-10        INV14919
#
#                                          Description Qty. Sold Sales Price  \
# 0  ActivWall 88 electronic interactive whiteboard...      1.00  $1,899.00
# 1  Mount Upgrade Kit with DLP ultra short-throw. ...      1.00  $1,599.00
# 2  Just Lamps - Diamond Lamps - PRM-10/20 replace...     25.00     $99.00
# 3      HoverCam Solo 5.  5 megapixel document camera      1.00    $269.00
# 4      HoverCam Solo 5.  5 megapixel document camera      1.00    $269.00
#
#       Revenue Address: Billing Address State Customer/Project: Company Name
# 0  $1,899.00                              AK       Alaska Works Partnership
# 1  $1,599.00                              AK       Alaska Works Partnership
# ...

# %%
sales_2017.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2017-07-06        INV16708
# 1   NaN  Invoice 2017-07-06        INV16708
# 2   NaN  Invoice 2017-07-06        INV16708
# 3   NaN  Invoice 2017-07-06        INV16708
# 4   NaN  Invoice 2017-07-06        INV16708
#
#                                          Description  Qty. Sold Sales Price  \
# 0  Additional Schlessinger Media 9-12 Content Pac...        1.0    $295.00
# 1  Additional Schlessinger Media K-8 Content Pack...        1.0    $495.00
# 2            Algebra'scool Content Package (Renewal)        1.0    $500.00
# 3   K-12 Super Core Content Package (2011) (Renewal)        1.0  $2,500.00
# 4  K-6 Supplemental Content Package (2011) (Renewal)        1.0    $250.00
#
#       Revenue Address: Billing Address State Customer/Project: Company Name
# 0    $295.00                              AK            Nome Public Schools
# 1    $495.00                              AK            Nome Public Schools
# ...

# %%
sales_2018.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2018-04-16        INV17524
# 1   NaN  Invoice 2018-04-16        INV17524
# 2   NaN  Invoice 2018-03-31        INV17480
# 3   NaN  Invoice 2018-03-31        INV17480
# 4   NaN  Invoice 2018-03-31        INV17480
#
#                                          Description  Qty. Sold Sales Price  \
# 0                                  BoxLight MimioHub        3.0     $40.00
# 1                                           MimioPad        3.0    $299.00
# 2  Clear Touch CTI-STAND-FIXM: Fixed Mobile Stand...        1.0    $599.00
# 3  Clear Touch Fixed Wall Mount (for use with ALL...        2.0    $149.00
# 4  Clear Touch Panel 65" 6000 Series 4K Interacti...        2.0  $2,899.00
#
#       Revenue Address: Billing Address State  Customer/Project: Company Name
# 0    $120.00                              AK    Ketchikan Gateway Borough SD
# 1    $897.00                              AK    Ketchikan Gateway Borough SD
# ...

# %%
sales_2019.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2019-01-07        INV18164
# 1   NaN  Invoice 2019-11-18        INV18895
# 2   NaN  Invoice 2019-11-18        INV18895
# 3   NaN  Invoice 2019-07-01        INV18511
# 4   NaN  Invoice 2019-07-01        INV18511
#
#                                          Description Qty. Sold Sales Price  \
# 0  PRM-10/20 replacement bulb (a 6" lens offset t...        25     $129.00
# 1              ActivConnect OPS - AP PC for Android.         1     $199.00
# 2  ActivPanel Titanium 75" - 4 x Pen, Vesa Mount,...         1   $4,799.00
# 3  Safari Montage - K-12 Super Core Content Packa...         1   $2,500.00
# 4  Safari Montage Additional Schlessinger Media K...         1     $495.00
#
#      Revenue Address: Billing Address State Customer/Project: Company Name
# 0  $3,225.00                             AK            Clark Middle School
# 1    $199.00                             AK                 Credit Union 1
# ...

# %%
sales_2020.head()
# Out:
#    Item     Type       Date Document Number  \
# 0   NaN  Invoice 2020-07-07        INV19283
# 1   NaN  Invoice 2020-07-07        INV19283
# 2   NaN  Invoice 2020-07-07        INV19283
# 3   NaN  Invoice 2020-07-07        INV19283
# 4   NaN  Invoice 2020-07-07        INV19283
#
#                                          Description Qty. Sold Sales Price  \
# 0  Safari Montage - K-12 Super Core Content Packa...         1   $2,750.00
# 1  Safari Montage Additional Schlessinger Media K...         1     $495.00
# 2  Safari Montage Algebra's Cool - Content Packag...         1     $500.00
# 3  SAFARI Montage Learning Object Repository Annu...         1   $1,500.00
# 4  Safari Montage Math's Cool - Content Package (...         1     $500.00
#
#      Revenue Address: Billing Address State Customer/Project: Company Name
# 0  $2,750.00                             AK            Nome Public Schools
# 1    $495.00                             AK            Nome Public Schools
# ...

# %%
sales_2020[sales_2020['Customer/Project: Company Name']=='Knolls Vista Elementary School']
# Out:
#      Item     Type       Date Document Number  \
# 662   NaN  Invoice 2020-04-09        INV19158
# 663   NaN  Invoice 2020-07-22        INV19309
# 664   NaN  Invoice 2020-04-09        INV19158
# 665   NaN  Invoice 2020-04-09        INV19158
# 666   NaN  Invoice 2020-04-09        INV19158
#
#                                            Description Qty. Sold Sales Price  \
# 662                                       Installation         1   $4,000.00
# 663                                       Installation         1       $0.00
# 664  LU UNO turn-key system for: One interactive vi...         1  $16,500.00
# 665                     LU Wireless HDMI IOGEAR 1 port         1     $500.00
# 666           Microphone Shure BLX14R kit with headset         1     $625.00
#
#         Revenue Address: Billing Address State  Customer/Project: Company Name
# 662   $4,000.00                             WA  Knolls Vista Elementary School
# ...

# %%
#Report_Card.drop(Report_Card.index[(Report_Card["Lectures"] == "German")],axis=0,inplace=True)
sales_2020.drop(sales_2020.index[(sales_2020['Customer/Project: Company Name']=='Knolls Vista Elementary School')],axis=0,inplace=True)
sales_2020[sales_2020['Customer/Project: Company Name']=='Knolls Vista Elementary School']
# Out:
# Empty DataFrame
# Columns: [Item, Type, Date, Document Number, Description, Qty. Sold, Sales Price, Revenue, Address: Billing Address State, Customer/Project: Company Name]
# Index: []

# %% [markdown]
# # Check all the Columns all Match

# %%
sales_2015.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
sales_2016.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
sales_2017.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
sales_2018.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
sales_2019.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
sales_2020.columns
# Out:
# Index(['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'Address: Billing Address State',
#        'Customer/Project: Company Name'],
#       dtype='object')

# %%
cols_2015 = ['sales_2015', sales_2015.columns]
cols_2016 = ['sales_2015', sales_2016.columns]
cols_2017 = ['sales_2015', sales_2017.columns]
cols_2018 = ['sales_2015', sales_2018.columns]

# %%
all_cols = {'sales_2015':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                        'Sales Price', 'Revenue', 'Address: Billing Address State',
                        'Customer/Project: Company Name'],
            
            'sales_2016':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                        'Sales Price', 'Revenue', 'Address: Billing Address State',
                        'Customer/Project: Company Name'] ,
           
           'sales_2017':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                       'Sales Price', 'Revenue', 'Address: Billing Address State',
                       'Customer/Project: Company Name'],
            
            'sales_2018':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                        'Sales Price', 'Revenue', 'Address: Billing Address State',
                        'Customer/Project: Company Name'],
            
            'sales_2019':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                        'Sales Price', 'Revenue', 'Address: Billing Address State',
                        'Customer/Project: Company Name'],
            
            'sales_2020':['Item', 'Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
                        'Sales Price', 'Revenue', 'Address: Billing Address State',
                        'Customer/Project: Company Name']
           }
all_cols
all_cols = pd.DataFrame(data=all_cols)
all_cols
# Out:
#                        sales_2015                      sales_2016  \
# 0                            Item                            Item
# 1                            Type                            Type
# 2                            Date                            Date
# 3                 Document Number                 Document Number
# 4                     Description                     Description
# 5                       Qty. Sold                       Qty. Sold
# 6                     Sales Price                     Sales Price
# 7                         Revenue                         Revenue
# 8  Address: Billing Address State  Address: Billing Address State
# 9  Customer/Project: Company Name  Customer/Project: Company Name
#
#                        sales_2017                      sales_2018  \
# 0                            Item                            Item
# 1                            Type                            Type
# ...

# %% [markdown]
# # Check Shapes

# %%
shape_2015 = ['sales_2015', sales_2015.shape]
shape_2016 = ['sales_2016', sales_2016.shape]
shape_2017 = ['sales_2017', sales_2017.shape]
shape_2018 = ['sales_2018', sales_2018.shape]
shape_2019 = ['sales_2019', sales_2019.shape]
shape_2020 = ['sales_2020', sales_2020.shape]

print(shape_2015)
print(shape_2016)
print(shape_2017)
print(shape_2018)
print(shape_2019)
print(shape_2020)
# Out:
# ['sales_2015', (2529, 10)]
# ['sales_2016', (2181, 10)]
# ['sales_2017', (1722, 10)]
# ['sales_2018', (1373, 10)]
# ['sales_2019', (1265, 10)]
# ['sales_2020', (1072, 10)]

# %%
all_shapes = {'sales_2015': [2529, 10],
              'sales_2016': [2181, 10],
              'sales_2017': [1722, 10],
              'sales_2018': [1373, 10],
              'sales_2019': [1265, 10],
              'sales_2020': [1077, 10],
             }
all_shapes
# Out:
# {'sales_2015': [2529, 10],
#  'sales_2016': [2181, 10],
#  'sales_2017': [1722, 10],
#  'sales_2018': [1373, 10],
#  'sales_2019': [1265, 10],
#  'sales_2020': [1077, 10]}

# %%
#shape_headers = df.iloc[0]
all_shapes = pd.DataFrame(data=all_shapes)
all_shapes = all_shapes.rename(index = {0:'rows', 1:'columns'})
all_shapes
# Out:
#          sales_2015  sales_2016  sales_2017  sales_2018  sales_2019  \
# rows           2529        2181        1722        1373        1265
# columns          10          10          10          10          10
#
#          sales_2020
# rows           1077
# columns          10

# %%
origs_row_count = all_shapes.iloc[0].sum()
origs_row_count
# Out:
# 10147

# %% [markdown]
# # Find Nulls of Originals

# %%
np.where(pd.isnull(sales_2020))
# Out:
# (array([   0,    1,    2, ..., 1069, 1070, 1071]),
#  array([0, 0, 0, ..., 0, 0, 0]))

# %%
sales_2020.isnull().sum()
# Out:
# Item                              1072
# Type                                14
# Date                                14
# Document Number                     14
# Description                         14
# Qty. Sold                           14
# Sales Price                         14
# Revenue                             14
# Address: Billing Address State      14
# Customer/Project: Company Name      14
# dtype: int64

# %%
sales_2019.isnull().sum()
# Out:
# Item                              1265
# Type                                12
# Date                                12
# Document Number                     12
# Description                         12
# Qty. Sold                           12
# Sales Price                         13
# Revenue                             12
# Address: Billing Address State      13
# Customer/Project: Company Name      12
# dtype: int64

# %%
sales_2018.isnull().sum()
# Out:
# Item                              1373
# Type                                24
# Date                                24
# Document Number                     24
# Description                         24
# Qty. Sold                           24
# Sales Price                         24
# Revenue                             24
# Address: Billing Address State      24
# Customer/Project: Company Name      25
# dtype: int64

# %%
sales_2017.isnull().sum()
# Out:
# Item                              1722
# Type                                20
# Date                                20
# Document Number                     20
# Description                         20
# Qty. Sold                           20
# Sales Price                         20
# Revenue                             20
# Address: Billing Address State      20
# Customer/Project: Company Name      20
# dtype: int64

# %%
sales_2016.isnull().sum()
# Out:
# Item                              2181
# Type                                18
# Date                                18
# Document Number                     18
# Description                         18
# Qty. Sold                           18
# Sales Price                         20
# Revenue                             18
# Address: Billing Address State      20
# Customer/Project: Company Name      18
# dtype: int64

# %%
sales_2015.isnull().sum()
# Out:
# Item                              2529
# Type                                 0
# Date                                 0
# Document Number                      0
# Description                          0
# Qty. Sold                            0
# Sales Price                          1
# Revenue                              0
# Address: Billing Address State     153
# Customer/Project: Company Name       0
# dtype: int64

# %% [markdown]
# # Merge Datasets to One Large Dataset

# %%
frames = [sales_2020, sales_2019, sales_2018, sales_2017, sales_2016, sales_2015]
sales = pd.concat(frames)
sales = sales.drop('Item',axis=1)
sales = sales.rename({'Address: Billing Address State' :'State', 'Customer/Project: Company Name': 'Customer' }, axis=1)
sales
# Out:
#          Type       Date Document Number  \
# 0     Invoice 2020-07-07        INV19283
# 1     Invoice 2020-07-07        INV19283
# 2     Invoice 2020-07-07        INV19283
# 3     Invoice 2020-07-07        INV19283
# 4     Invoice 2020-07-07        INV19283
# ...       ...        ...             ...
# 2524  Invoice 2015-10-29        INV14532
# 2525  Invoice 2015-10-29        INV14548
# 2526  Invoice 2015-07-28        INV14025
# 2527  Invoice 2015-02-26        INV13418
# 2528  Invoice 2015-10-14        INV14433
#
#                                             Description Qty. Sold Sales Price  \
# 0     Safari Montage - K-12 Super Core Content Packa...         1   $2,750.00
# 1     Safari Montage Additional Schlessinger Media K...         1     $495.00
# 2     Safari Montage Algebra's Cool - Content Packag...         1     $500.00
# 3     SAFARI Montage Learning Object Repository Annu...         1   $1,500.00
# ...

# %%
origs_row_count == sales.shape[0]
# Out:
# False

# %%
sales.shape
# Out:
# (10142, 9)

# %%
msno.matrix(sales);

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10142 entries, 0 to 2528
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             10054 non-null  object
#  1   Date             10054 non-null  datetime64[ns]
#  2   Document Number  10054 non-null  object
#  3   Description      10054 non-null  object
#  4   Qty. Sold        10054 non-null  object
#  5   Sales Price      10050 non-null  object
#  6   Revenue          10054 non-null  object
#  7   State            9898 non-null   object
#  8   Customer         10053 non-null  object
# dtypes: datetime64[ns](1), object(8)
# memory usage: 792.3+ KB

# %%
sales.isna().sum()
# Out:
# Type                88
# Date                88
# Document Number     88
# Description         88
# Qty. Sold           88
# Sales Price         92
# Revenue             88
# State              244
# Customer            89
# dtype: int64

# %%
sales.columns
# Out:
# Index(['Type', 'Date', 'Document Number', 'Description', 'Qty. Sold',
#        'Sales Price', 'Revenue', 'State', 'Customer'],
#       dtype='object')

# %% [markdown]
# # Rename Columns

# %%
sales = sales.rename({'Qty. Sold':'Qty' , 'Sales Price':'Unit Price'},axis=1)
sales
# Out:
#          Type       Date Document Number  \
# 0     Invoice 2020-07-07        INV19283
# 1     Invoice 2020-07-07        INV19283
# 2     Invoice 2020-07-07        INV19283
# 3     Invoice 2020-07-07        INV19283
# 4     Invoice 2020-07-07        INV19283
# ...       ...        ...             ...
# 2524  Invoice 2015-10-29        INV14532
# 2525  Invoice 2015-10-29        INV14548
# 2526  Invoice 2015-07-28        INV14025
# 2527  Invoice 2015-02-26        INV13418
# 2528  Invoice 2015-10-14        INV14433
#
#                                             Description  Qty  Unit Price  \
# 0     Safari Montage - K-12 Super Core Content Packa...    1   $2,750.00
# 1     Safari Montage Additional Schlessinger Media K...    1     $495.00
# 2     Safari Montage Algebra's Cool - Content Packag...    1     $500.00
# 3     SAFARI Montage Learning Object Repository Annu...    1   $1,500.00
# 4     Safari Montage Math's Cool - Content Package (...    1     $500.00
# ...

# %% [markdown]
# # Date Transformations

# %%
sales['Date'] = pd.to_datetime(sales['Date'])
sales['Date']
# Out:
# 0      2020-07-07
# 1      2020-07-07
# 2      2020-07-07
# 3      2020-07-07
# 4      2020-07-07
#           ...
# 2524   2015-10-29
# 2525   2015-10-29
# 2526   2015-07-28
# 2527   2015-02-26
# 2528   2015-10-14
# Name: Date, Length: 10142, dtype: datetime64[ns]

# %%
sales['Year'] = sales['Date'].dt.year
sales['Year']
# Out:
# 0       2020.0
# 1       2020.0
# 2       2020.0
# 3       2020.0
# 4       2020.0
#          ...
# 2524    2015.0
# 2525    2015.0
# 2526    2015.0
# 2527    2015.0
# 2528    2015.0
# Name: Year, Length: 10142, dtype: float64

# %%
sales['Month'] = sales['Date'].dt.month
sales['Month']
# Out:
# 0        7.0
# 1        7.0
# 2        7.0
# 3        7.0
# 4        7.0
#         ...
# 2524    10.0
# 2525    10.0
# 2526     7.0
# 2527     2.0
# 2528    10.0
# Name: Month, Length: 10142, dtype: float64

# %%
sales['Date']
# Out:
# 0      2020-07-07
# 1      2020-07-07
# 2      2020-07-07
# 3      2020-07-07
# 4      2020-07-07
#           ...
# 2524   2015-10-29
# 2525   2015-10-29
# 2526   2015-07-28
# 2527   2015-02-26
# 2528   2015-10-14
# Name: Date, Length: 10142, dtype: datetime64[ns]

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10142 entries, 0 to 2528
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             10054 non-null  object
#  1   Date             10054 non-null  datetime64[ns]
#  2   Document Number  10054 non-null  object
#  3   Description      10054 non-null  object
#  4   Qty              10054 non-null  object
#  5   Unit Price       10050 non-null  object
#  6   Revenue          10054 non-null  object
#  7   State            9898 non-null   object
#  8   Customer         10053 non-null  object
#  9   Year             10054 non-null  float64
#  10  Month            10054 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(8)
# memory usage: 950.8+ KB

# %%
sales.head()
# Out:
#       Type       Date Document Number  \
# 0  Invoice 2020-07-07        INV19283
# 1  Invoice 2020-07-07        INV19283
# 2  Invoice 2020-07-07        INV19283
# 3  Invoice 2020-07-07        INV19283
# 4  Invoice 2020-07-07        INV19283
#
#                                          Description Qty Unit Price  \
# 0  Safari Montage - K-12 Super Core Content Packa...   1  $2,750.00
# 1  Safari Montage Additional Schlessinger Media K...   1    $495.00
# 2  Safari Montage Algebra's Cool - Content Packag...   1    $500.00
# 3  SAFARI Montage Learning Object Repository Annu...   1  $1,500.00
# 4  Safari Montage Math's Cool - Content Package (...   1    $500.00
#
#      Revenue State             Customer    Year  Month
# 0  $2,750.00    AK  Nome Public Schools  2020.0    7.0
# 1    $495.00    AK  Nome Public Schools  2020.0    7.0
# 2    $500.00    AK  Nome Public Schools  2020.0    7.0
# 3  $1,500.00    AK  Nome Public Schools  2020.0    7.0
# ...

# %% [markdown]
# # Anonymize Customers

# %%
customer_keys = pd.DataFrame(sales.groupby('Customer')['Date'].min())
customer_keys = customer_keys.reset_index()
customer_keys.columns = ['Customer', 'Customer since']

customer_keys
# Out:
#                            Customer Customer since
# 0                 ABSCO Alarms Inc.     2017-02-02
# 1     AGC Apprenticeship & Training     2020-07-07
# 2                           AMS.Net     2020-09-15
# 3        Aberdeen School District 5     2015-01-07
# 4       Abraham Lincoln Elem School     2017-05-30
# ...                             ...            ...
# 1012        Yaquina View Elementary     2015-07-23
# 1013    Yerington Elementary School     2015-09-29
# 1014          Yerington High School     2015-10-12
# 1015  Yerington Intermediate School     2018-09-19
# 1016      Yvonne Shaw Middle School     2015-03-17
#
# [1017 rows x 2 columns]

# %%
len(customer_keys['Customer'])
# Out:
# 1017

# %%
customer_keys['Customer ID'] = np.arange(100001, 100001 + int(len(customer_keys['Customer'])) ,1)

# %%
customer_keys
# Out:
#                            Customer Customer since  Customer ID
# 0                 ABSCO Alarms Inc.     2017-02-02       100001
# 1     AGC Apprenticeship & Training     2020-07-07       100002
# 2                           AMS.Net     2020-09-15       100003
# 3        Aberdeen School District 5     2015-01-07       100004
# 4       Abraham Lincoln Elem School     2017-05-30       100005
# ...                             ...            ...          ...
# 1012        Yaquina View Elementary     2015-07-23       101013
# 1013    Yerington Elementary School     2015-09-29       101014
# 1014          Yerington High School     2015-10-12       101015
# 1015  Yerington Intermediate School     2018-09-19       101016
# 1016      Yvonne Shaw Middle School     2015-03-17       101017
#
# [1017 rows x 3 columns]

# %%
customer_keys.isnull().sum()
# Out:
# Customer          0
# Customer since    0
# Customer ID       0
# dtype: int64

# %%
customer_keys.dropna(how='any', inplace=True)
customer_keys[customer_keys['Customer']=='NaN']
# Out:
# Empty DataFrame
# Columns: [Customer, Customer since, Customer ID]
# Index: []

# %%
customer_keys.isna().sum()
# Out:
# Customer          0
# Customer since    0
# Customer ID       0
# dtype: int64

# %%
customer_keys.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1017 entries, 0 to 1016
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Customer        1017 non-null   object
#  1   Customer since  1017 non-null   datetime64[ns]
#  2   Customer ID     1017 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 31.8+ KB

# %%
customer_keys
# Out:
#                            Customer Customer since  Customer ID
# 0                 ABSCO Alarms Inc.     2017-02-02       100001
# 1     AGC Apprenticeship & Training     2020-07-07       100002
# 2                           AMS.Net     2020-09-15       100003
# 3        Aberdeen School District 5     2015-01-07       100004
# 4       Abraham Lincoln Elem School     2017-05-30       100005
# ...                             ...            ...          ...
# 1012        Yaquina View Elementary     2015-07-23       101013
# 1013    Yerington Elementary School     2015-09-29       101014
# 1014          Yerington High School     2015-10-12       101015
# 1015  Yerington Intermediate School     2018-09-19       101016
# 1016      Yvonne Shaw Middle School     2015-03-17       101017
#
# [1017 rows x 3 columns]

# %%
customer_keys.to_csv('../data/processed/customer_keys.csv')

# %%
unique_customers = pd.Series(sales['Customer'].unique())
unique_customers.isna()
unique_customers.loc[1]
unique_customers.dropna(how='any', inplace=True)
unique_customers.isna().sum()
# Out:
# 0

# %%
unique_customers
# Out:
# 0                        Nome Public Schools
# 2              AGC Apprenticeship & Training
# 3                                    AMS.Net
# 4              Anacortes School District 103
# 5       Antelope Valley High School District
#                         ...
# 1013             Sunnyside Elementary School
# 1014                     Tenth Street School
# 1015           Arts & Technology High School
# 1016               Mountain View High School
# 1017                 Grove Elementary School
# Length: 1017, dtype: object

# %%
# customer_keys = pd.DataFrame({'Customer':sales['Customer'].unique(), 'customer since':sales.groupby('Customer')['Date'].min()} ).reset_index(drop=True)

# # customer_keys = customer_keys.sort_values(by=['customer since']).reset_index(drop=True)
# # customer_keys['customer id'] = np.arange(100001, len(customer_keys['customer id']),1)
# customer_keys
# USED A DIFFERENT CUSTOMER KEYS

# %%
print(sales.shape)
print(customer_keys.shape)
print(sales.shape[0] + customer_keys.shape[0] )
# Out:
# (10142, 11)
# (1017, 3)
# 11159

# %%
customer_keys.head()
# Out:
#                         Customer Customer since  Customer ID
# 0              ABSCO Alarms Inc.     2017-02-02       100001
# 1  AGC Apprenticeship & Training     2020-07-07       100002
# 2                        AMS.Net     2020-09-15       100003
# 3     Aberdeen School District 5     2015-01-07       100004
# 4    Abraham Lincoln Elem School     2017-05-30       100005

# %%
#sales= sales.merge(customer_keys, on='Customer')

# %%
sales
# Out:
#          Type       Date Document Number  \
# 0     Invoice 2020-07-07        INV19283
# 1     Invoice 2020-07-07        INV19283
# 2     Invoice 2020-07-07        INV19283
# 3     Invoice 2020-07-07        INV19283
# 4     Invoice 2020-07-07        INV19283
# ...       ...        ...             ...
# 9536  Invoice 2015-02-04        INV13303
# 9537  Invoice 2015-02-04        INV13308
# 9538  Invoice 2015-02-04        INV13305
# 9539  Invoice 2015-02-18        INV13372
# 9540  Invoice 2015-02-18        INV13370
#
#                                             Description  Qty  Unit Price  \
# 0     Safari Montage - K-12 Super Core Content Packa...    1     2750.00
# 1     Safari Montage Additional Schlessinger Media K...    1      495.00
# 2     Safari Montage Algebra's Cool - Content Packag...    1      500.00
# 3     SAFARI Montage Learning Object Repository Annu...    1     1500.00
# 4     Safari Montage Math's Cool - Content Package (...    1      500.00
# ...

# %% [markdown]
# # Find and remove NaN's

# %%
sales[sales.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Type, Date, Document Number, Description, Qty, Unit Price, Revenue, State, Customer, Year, Month, Sales Total, Customer since, Customer ID]
# Index: []

# %%
nan_values = sales[sales['Type'].isnull()]
rows_to_delete = nan_values.shape[0]
rows_to_delete
# Out:
# 0

# %%
nan_values = sales[sales['Type'].isnull()]
rows_to_drop = np.sort(nan_values.index)
#rows_to_drop = rows_to_drop.tolist()
len(rows_to_drop)
rows_to_drop
# Out:
# array([], dtype=int64)

# %%
sales = sales.drop(rows_to_drop).reset_index(drop=True)
sales.head(10)
# Out:
#       Type       Date Document Number  \
# 0  Invoice 2020-07-07        INV19283
# 1  Invoice 2020-07-07        INV19283
# 2  Invoice 2020-07-07        INV19283
# 3  Invoice 2020-07-07        INV19283
# 4  Invoice 2020-07-07        INV19283
# 5  Invoice 2020-07-07        INV19283
# 6  Invoice 2020-07-07        INV19283
# 7  Invoice 2019-07-01        INV18511
# 8  Invoice 2019-07-01        INV18511
# 9  Invoice 2019-07-01        INV18511
#
#                                          Description  Qty  Unit Price  \
# 0  Safari Montage - K-12 Super Core Content Packa...    1      2750.0
# 1  Safari Montage Additional Schlessinger Media K...    1       495.0
# 2  Safari Montage Algebra's Cool - Content Packag...    1       500.0
# 3  SAFARI Montage Learning Object Repository Annu...    1      1500.0
# 4  Safari Montage Math's Cool - Content Package (...    1       500.0
# 5  Safari Montage Video Ency 20th Century Content...    1       295.0
# ...

# %%
sales.isna().sum()
# Out:
# Type               0
# Date               0
# Document Number    0
# Description        0
# Qty                0
# Unit Price         0
# Revenue            0
# State              0
# Customer           0
# Year               0
# Month              0
# Sales Total        0
# Customer since     0
# Customer ID        0
# dtype: int64

# %%
sales.dropna(how='any', axis=0, inplace=True)

# %%
sales.isna().sum()
# Out:
# Type               0
# Date               0
# Document Number    0
# Description        0
# Qty                0
# Unit Price         0
# Revenue            0
# State              0
# Customer           0
# Year               0
# Month              0
# Sales Total        0
# Customer since     0
# Customer ID        0
# dtype: int64

# %% [markdown]
# # Object to Float or Int transformation

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   int64
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
#sales[["Qty. Sold", "Sales Price", "Revenue"]].apply(pd.to_numeric)
# didn't work have to convert to float then int

# %%
# DID NOT WORK

#sales['Revenue'] = sales['Revenue'].replace('(','-').replace(')','')
#sales['Revenue'] = sales['Revenue'].astype('float64').astype('int32')
# sales['Revenue'] = sales['Revenue'].replace(',','').replace('\$|,', '', regex=True).astype('float64').astype('int32')
# sales['Sales Price'] = sales['Sales Price'].replace(',','').replace('\$|,', '', regex=True)

# %%
sales['Revenue'] = sales['Revenue'].replace(',','').replace('\$|,', '', regex=True)

sales['Revenue'] = sales['Revenue'].astype(str).str.replace("(", "-").str.rstrip(")").astype(float)


sales['Unit Price'] = sales['Unit Price'].replace(',','').replace('\$|,', '', regex=True)
sales['Unit Price'] = sales['Unit Price'].astype(str).str.replace("(", "-").str.rstrip(")").astype(float)
sales['Unit Price'] = sales['Unit Price'].astype(float)

sales['Qty'] = sales['Qty'].replace(',','').replace('\$|,', '', regex=True)
sales['Qty'] = sales['Qty'].astype(float)



sales.head(10)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   float64
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(1), object(5)
# memory usage: 1.1+ MB
# ...

# %%
sales[sales['Revenue']<0]
# Out:
#              Type       Date Document Number  \
# 555   Credit Memo 2018-04-09             411
# 562   Credit Memo 2018-11-05             428
# 658   Credit Memo 2015-08-25             283
# 704   Credit Memo 2020-10-07             449
# 706   Credit Memo 2020-10-07             449
# ...           ...        ...             ...
# 9304  Credit Memo 2015-04-22             257
# 9306  Credit Memo 2015-04-22             257
# 9378  Credit Memo 2015-08-10             282
# 9426  Credit Memo 2015-04-09             244
# 9428  Credit Memo 2015-03-31             242
#
#                                             Description   Qty  Unit Price  \
# 555          HoverCam Solo 8 - 8.0 MP, USB 3.0, 30 fps.  -1.0       329.0
# 562   Promethean Academy - 1-Day Prof Development On...  -1.0      1550.0
# 658   Installation for replacement Promethean projec...  -2.0        75.0
# 704   Manual height adjustable mobile stand for use ... -14.0      1065.0
# ...

# %%
sales['Qty'] = sales['Qty'].replace(',','').replace('\$|,', '', regex=True)
sales['Qty'] = sales['Qty'].astype('float64').astype('int32')
sales.head()
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   int32
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int32(1), int64(1), object(5)
# memory usage: 1.1+ MB

# %%
sales['Unit Price'] = sales['Unit Price'].replace(',','').replace('\$|,', '', regex=True)
sales['Unit Price'] = sales['Unit Price'].astype('float64')
sales.head()
#sales.info()
# Out:
#       Type       Date Document Number  \
# 0  Invoice 2020-07-07        INV19283
# 1  Invoice 2020-07-07        INV19283
# 2  Invoice 2020-07-07        INV19283
# 3  Invoice 2020-07-07        INV19283
# 4  Invoice 2020-07-07        INV19283
#
#                                          Description  Qty  Unit Price  \
# 0  Safari Montage - K-12 Super Core Content Packa...    1      2750.0
# 1  Safari Montage Additional Schlessinger Media K...    1       495.0
# 2  Safari Montage Algebra's Cool - Content Packag...    1       500.0
# 3  SAFARI Montage Learning Object Repository Annu...    1      1500.0
# 4  Safari Montage Math's Cool - Content Package (...    1       500.0
#
#    Revenue State             Customer    Year  Month  Sales Total  \
# 0   2750.0    AK  Nome Public Schools  2020.0    7.0       2750.0
# 1    495.0    AK  Nome Public Schools  2020.0    7.0        495.0
# 2    500.0    AK  Nome Public Schools  2020.0    7.0        500.0
# ...

# %%
sales[sales['Type']=="Credit Memo"]
# Out:
#              Type       Date Document Number  \
# 555   Credit Memo 2018-04-09             411
# 562   Credit Memo 2018-11-05             428
# 576   Credit Memo 2018-12-26             429
# 658   Credit Memo 2015-08-25             283
# 704   Credit Memo 2020-10-07             449
# ...           ...        ...             ...
# 9304  Credit Memo 2015-04-22             257
# 9306  Credit Memo 2015-04-22             257
# 9378  Credit Memo 2015-08-10             282
# 9426  Credit Memo 2015-04-09             244
# 9428  Credit Memo 2015-03-31             242
#
#                                             Description  Qty  Unit Price  \
# 555          HoverCam Solo 8 - 8.0 MP, USB 3.0, 30 fps.   -1       329.0
# 562   Promethean Academy - 1-Day Prof Development On...   -1      1550.0
# 576                           VTP-65 Wall Mount bracket   -1         0.0
# 658   Installation for replacement Promethean projec...   -2        75.0
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   int32
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int32(1), int64(1), object(5)
# memory usage: 1.1+ MB

# %%
sales['Qty'] = sales['Qty'].replace(',','')
sales['Qty'] = sales['Qty'].astype(int)
#sales['Qty. Sold'] = pd.to_numeric(sales['Qty. Sold'])

sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   int64
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# # Object to String Transformations

# %%
sales['Description'] = sales['Description'].astype(str)
sales["State"] = sales["State"].astype(str)
sales['Customer'] = sales['Customer'].astype(str)
sales['Document Number'] = sales['Document Number'].astype(str)


sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9541 entries, 0 to 9540
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Type             9541 non-null   object
#  1   Date             9541 non-null   datetime64[ns]
#  2   Document Number  9541 non-null   object
#  3   Description      9541 non-null   object
#  4   Qty              9541 non-null   int64
#  5   Unit Price       9541 non-null   float64
#  6   Revenue          9541 non-null   float64
#  7   State            9541 non-null   object
#  8   Customer         9541 non-null   object
#  9   Year             9541 non-null   float64
#  10  Month            9541 non-null   float64
#  11  Sales Total      9541 non-null   float64
#  12  Customer since   9541 non-null   datetime64[ns]
#  13  Customer ID      9541 non-null   int64
# dtypes: datetime64[ns](2), float64(5), int64(2), object(5)
# memory usage: 1.1+ MB

# %% [markdown]
# # Calculate Sales Total

# %%
sales['Sales Total'] = sales['Qty'] * sales['Unit Price']
sales.head()
# Out:
#       Type       Date Document Number  \
# 0  Invoice 2020-07-07        INV19283
# 1  Invoice 2020-07-07        INV19283
# 2  Invoice 2020-07-07        INV19283
# 3  Invoice 2020-07-07        INV19283
# 4  Invoice 2020-07-07        INV19283
#
#                                          Description  Qty  Unit Price  \
# 0  Safari Montage - K-12 Super Core Content Packa...    1      2750.0
# 1  Safari Montage Additional Schlessinger Media K...    1       495.0
# 2  Safari Montage Algebra's Cool - Content Packag...    1       500.0
# 3  SAFARI Montage Learning Object Repository Annu...    1      1500.0
# 4  Safari Montage Math's Cool - Content Package (...    1       500.0
#
#    Revenue State             Customer    Year  Month  Sales Total  \
# 0   2750.0    AK  Nome Public Schools  2020.0    7.0       2750.0
# 1    495.0    AK  Nome Public Schools  2020.0    7.0        495.0
# 2    500.0    AK  Nome Public Schools  2020.0    7.0        500.0
# ...

# %% [markdown]
# # Re-order Columns

# %%
print(sales.columns)
print(len(sales.columns))
# Out:
# Index(['Type', 'Date', 'Document Number', 'Description', 'Qty', 'Unit Price',
#        'Revenue', 'State', 'Customer', 'Year', 'Month', 'Sales Total',
#        'Customer since', 'Customer ID'],
#       dtype='object')
# 14

# %%
print(sales.columns)
print(len(sales.columns))
# Out:
# Index(['Type', 'Date', 'Document Number', 'Description', 'Qty', 'Unit Price',
#        'Revenue', 'State', 'Customer', 'Year', 'Month', 'Sales Total',
#        'Customer since', 'Customer ID'],
#       dtype='object')
# 14

# %%
sales = sales[[ 'Customer ID','Customer', 'Type', 'Date', 'Year', 'Month', 'Document Number', 'Description', 'Qty',
       'Unit Price', 'Sales Total', 'Revenue', 'State']]
sales.head(10)
# Out:
#    Customer ID             Customer     Type       Date    Year  Month  \
# 0       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 1       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 2       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 3       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 4       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 5       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 6       100625  Nome Public Schools  Invoice 2020-07-07  2020.0    7.0
# 7       100625  Nome Public Schools  Invoice 2019-07-01  2019.0    7.0
# 8       100625  Nome Public Schools  Invoice 2019-07-01  2019.0    7.0
# 9       100625  Nome Public Schools  Invoice 2019-07-01  2019.0    7.0
#
#   Document Number                                        Description  Qty  \
# 0        INV19283  Safari Montage - K-12 Super Core Content Packa...    1
# ...

# %%
credit_memos = sales[sales['Type']=='Credit Memo']
credit_memos
# Out:
#       Customer ID                                  Customer         Type  \
# 555        100615                  National School District  Credit Memo
# 562        100615                  National School District  Credit Memo
# 576        100615                  National School District  Credit Memo
# 658        100668                    Oxnard School District  Credit Memo
# 704        100672                  Palm Lane Charter School  Credit Memo
# ...           ...                                       ...          ...
# 9304       100790     San Mateo-Foster City School District  Credit Memo
# 9306       100790     San Mateo-Foster City School District  Credit Memo
# 9378       100628  North County Joint Union School District  Credit Memo
# 9426       100091           Burbank Unified School District  Credit Memo
# 9428       100424                   Jefferson Middle School  Credit Memo
#
#            Date    Year  Month Document Number  \
# ...

# %%
credit_memos.describe()
# Out:
#          Customer ID         Year       Month         Qty    Unit Price  \
# count     193.000000   193.000000  193.000000  193.000000    193.000000
# mean   100501.290155  2016.212435    6.683938   -2.984456    768.984249
# std       279.658960     1.199588    3.367832    9.307522   1542.672215
# min    100004.000000  2015.000000    1.000000 -107.000000      0.000000
# 25%    100292.000000  2015.000000    3.000000   -2.000000     99.000000
# 50%    100542.000000  2016.000000    7.000000   -1.000000    225.000000
# 75%    100728.000000  2017.000000   10.000000   -1.000000    879.000000
# max    100990.000000  2020.000000   12.000000    0.000000  12600.000000
#
#          Sales Total        Revenue
# count     193.000000     193.000000
# mean    -1897.980984   -1903.745233
# std      8191.926491    8190.955643
# min   -104325.000000 -104325.000000
# 25%     -1199.000000   -1199.000000
# 50%      -420.000000    -425.000000
# 75%      -125.000000    -129.000000
# ...

# %%
credit_sums = credit_memos[['Customer', 'Year', 'Sales Total']].groupby('Year').sum()
credit_sums = credit_sums.reset_index()
credit_sums['Year'] = credit_sums['Year'].astype(int)
credit_sums
# Out:
#    Year  Sales Total
# 0  2015    -55501.97
# 1  2016   -128337.86
# 2  2017    -45621.77
# 3  2018    -12560.23
# 4  2019   -107248.50
# 5  2020    -17040.00

# %%
credit_sums.sum()
# Out:
# Year            12105.00
# Sales Total   -366310.33
# dtype: float64

# %% [markdown]
# # REMOVE CREDIT MEMOS

# %%
sales = sales[sales['Qty']>0]
sales
# Out:
#       Customer ID                       Customer     Type       Date    Year  \
# 0          100625            Nome Public Schools  Invoice 2020-07-07  2020.0
# 1          100625            Nome Public Schools  Invoice 2020-07-07  2020.0
# 2          100625            Nome Public Schools  Invoice 2020-07-07  2020.0
# 3          100625            Nome Public Schools  Invoice 2020-07-07  2020.0
# 4          100625            Nome Public Schools  Invoice 2020-07-07  2020.0
# ...           ...                            ...      ...        ...     ...
# 9534       100717    Quil Ceda Elementary School  Invoice 2015-01-21  2015.0
# 9537       100915            Tenth Street School  Invoice 2015-02-04  2015.0
# 9538       100041  Arts & Technology High School  Invoice 2015-02-04  2015.0
# 9539       100604      Mountain View High School  Invoice 2015-02-18  2015.0
# 9540       100353        Grove Elementary School  Invoice 2015-02-18  2015.0
#
#       Month Document Number  \
# ...

# %%
sales['Type'].value_counts()
# Out:
# Invoice    9318
# Name: Type, dtype: int64

# %% [markdown]
# # SAVE FILE

# %%
sales.to_csv('../data/processed/sales.csv')

# %% [markdown]
# # Clean up

# %% [markdown]
# # Document Number & Description to strings

# %% [markdown]
# ## Drop trailing zeros on months

# %% [markdown]
# ## convert all number columns to integers *lose the pennies*
